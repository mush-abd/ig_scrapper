# %%
import json

with open("../output.json", "r") as f:
    data = json.load(f)


keys = data.keys()
print(keys)
# Out:
# dict_keys(['inputUrl', 'id', 'username', 'url', 'fullName', 'biography', 'externalUrls', 'externalUrl', 'externalUrlShimmed', 'followersCount', 'followsCount', 'hasChannel', 'highlightReelCount', 'isBusinessAccount', 'joinedRecently', 'businessCategoryName', 'private', 'verified', 'profilePicUrl', 'profilePicUrlHD', 'igtvVideoCount', 'relatedProfiles', 'latestIgtvVideos', 'postsCount', 'latestPosts', 'businessAddress', 'fbid'])

# %%
import json

with open("../posts.jsonl", "r") as f:
    data = []
    for line in f:
        data.append(json.loads(line))


keys = set()
for item in data:
    keys.update(item.keys())

print(keys)
# Out:
# {'ownerUsername', 'audioUrl', 'inputUrl', 'commentsCount', 'firstComment', 'productType', 'ownerFullName', 'taggedUsers', 'type', 'videoDuration', 'paidPartnership', 'hashtags', 'isCommentsDisabled', 'alt', 'isPinned', 'shortCode', 'timestamp', 'latestComments', 'videoPlayCount', 'caption', 'images', 'coauthorProducers', 'url', 'videoViewCount', 'dimensionsWidth', 'dimensionsHeight', 'locationName', 'likesCount', 'id', 'mentions', 'videoUrl', 'displayUrl', 'musicInfo', 'locationId', 'childPosts', 'ownerId'}

# %%
import json

with open("../reels.jsonl", "r") as f:
    data = []
    for line in f:
        data.append(json.loads(line))


keys = set()
for item in data:
    keys.update(item.keys())

print(keys)
print(data[0].keys())
# Out:
# {'ownerUsername', 'audioUrl', 'inputUrl', 'commentsCount', 'firstComment', 'productType', 'ownerFullName', 'taggedUsers', 'type', 'videoDuration', 'paidPartnership', 'hashtags', 'isCommentsDisabled', 'alt', 'isPinned', 'shortCode', 'timestamp', 'latestComments', 'videoPlayCount', 'caption', 'images', 'coauthorProducers', 'url', 'dimensionsWidth', 'videoViewCount', 'dimensionsHeight', 'locationName', 'likesCount', 'id', 'mentions', 'videoUrl', 'displayUrl', 'musicInfo', 'locationId', 'childPosts', 'ownerId'}
# dict_keys(['id', 'type', 'shortCode', 'caption', 'hashtags', 'mentions', 'url', 'commentsCount', 'dimensionsHeight', 'dimensionsWidth', 'images', 'videoUrl', 'likesCount', 'timestamp', 'ownerFullName', 'ownerUsername', 'ownerId', 'isPinned', 'productType', 'videoDuration', 'inputUrl', 'firstComment', 'latestComments', 'displayUrl', 'audioUrl', 'alt', 'videoViewCount', 'videoPlayCount', 'childPosts', 'taggedUsers', 'musicInfo', 'coauthorProducers', 'isCommentsDisabled'])

# %%
import json

with open("../comments.jsonl", "r") as f:
    data = []
    for line in f:
        data.append(json.loads(line))


# keys = set()
# for item in data:
#     keys.update(item.keys())

# print(keys)
print(data[0].keys())
# Out:
# dict_keys(['postUrl', 'commentUrl', 'id', 'text', 'ownerUsername', 'ownerProfilePicUrl', 'timestamp', 'repliesCount', 'replies', 'likesCount', 'owner'])
